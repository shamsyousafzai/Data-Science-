# %%
import pandas as pd

# %%
df = pd.read_csv("countries.csv")

# %%
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# 5     Afghanistan  1977    14880372
# 6     Afghanistan  1982    12881816
# 7     Afghanistan  1987    13867957
# 8     Afghanistan  1992    16317921
# 9     Afghanistan  1997    22227415
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 12        Albania  1952     1282697
# 13        Albania  1957     1476505
# 14        Albania  1962     1728137
# 15        Albania  1967     1984060
# 16        Albania  1972     2263554
# 17        Albania  1977     2509048
# 18        Albania  1982     2780097
# 19        Albania  1987     3075321
# 20        Albania  1992     3326498
# 21        Albania  1997     3428038
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 24        Algeria  1952     9279525
# ...

# %%
g = df.groupby("country")

# %%
for country , country_df in g:
    print(country)
    print(country_df)
# Out:
# Afghanistan
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923
# Albania
#     country  year  population
# 12  Albania  1952     1282697
# 13  Albania  1957     1476505
# 14  Albania  1962     1728137
# 15  Albania  1967     1984060
# 16  Albania  1972     2263554
# 17  Albania  1977     2509048
# 18  Albania  1982     2780097
# 19  Albania  1987     3075321
# 20  Albania  1992     3326498
# 21  Albania  1997     3428038
# 22  Albania  2002     3508512
# 23  Albania  2007     3600523
# Algeria
#     country  year  population
# 24  Algeria  1952     9279525
# ...

# %%
afg = g.get_group("Afghanistan")

# %%
afg
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
g.max()
# Out:
#                           year  population
# country
# Afghanistan               2007    31889923
# Albania                   2007     3600523
# Algeria                   2007    33333216
# Angola                    2007    12420476
# Argentina                 2007    40301927
# Australia                 2007    20434176
# Austria                   2007     8199783
# Bahrain                   2007      708573
# Bangladesh                2007   150448339
# Belgium                   2007    10392226
# Benin                     2007     8078314
# Bolivia                   2007     9119152
# Bosnia and Herzegovina    2007     4552198
# Botswana                  2007     1639131
# Brazil                    2007   190010647
# Bulgaria                  2007     8971958
# Burkina Faso              2007    14326203
# Burundi                   2007     8390505
# Cambodia                  2007    14131858
# Cameroon                  2007    17696293
# Canada                    2007    33390141
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
afg.plot()
