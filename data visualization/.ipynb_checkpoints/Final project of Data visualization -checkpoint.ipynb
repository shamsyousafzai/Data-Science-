# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Topic_Survey_ASsignment.csv")

# %%
df
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
# 5            Machine Learning             1629                  477
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136
# 5              74

# %%
df.sort_values(by=['Very interested'], ascending=False)
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics             1688                  444
# 5            Machine Learning             1629                  477
# 3          Data Visualization             1340                  734
# 0   Big Data (Spark / Hadoop)             1332                  729
# 4               Deep Learning             1263                  770
# 2             Data Journalism              429                 1081
#
#    Not interested
# 1              60
# 5              74
# 3             102
# 0             127
# 4             136
# 2             610

# %%
df
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
# 5            Machine Learning             1629                  477
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136
# 5              74

# %%
colors_list = ['#5cb85c','#5bc0de','#d9534f']

df.plot(kind="bar", figsize = (20,8), width = 0.8, fontsize = 14, color = colors_list , edgecolor = None)
plt.title("percentage of repondents interest in data science area", fontsize =16)
# ("Data Analysis / Statistic","Machine Learning")
plt.show()

# %%
df1 = pd.read_csv("Police_Department.csv")

# %%
df1
# Out:
#         IncidntNum         Category  \
# 0        120058272      WEAPON LAWS
# 1        120058272      WEAPON LAWS
# 2        141059263         WARRANTS
# 3        160013662     NON-CRIMINAL
# 4        160002740     NON-CRIMINAL
# 5        160002869          ASSAULT
# 6        160003130   OTHER OFFENSES
# 7        160003259     NON-CRIMINAL
# 8        160003970         WARRANTS
# 9        160003641   MISSING PERSON
# 10       160086863    LARCENY/THEFT
# 11       160004053     NON-CRIMINAL
# 12       160073014   OTHER OFFENSES
# 13       140776777          ASSAULT
# 14       160004069         BURGLARY
# 15       160004150  STOLEN PROPERTY
# 16       160004241          ROBBERY
# 17       160004558          ASSAULT
# 18       160004655          ASSAULT
# 19       160004837    LARCENY/THEFT
# 20       160005421            FRAUD
# 21       160005750         WARRANTS
# 22       160005841    DRUG/NARCOTIC
# 23       160005841   OTHER OFFENSES
# 24       160006071          ASSAULT
# ...
