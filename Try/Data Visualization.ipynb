# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("master.csv")
df1.set_index("country", inplace = True)
df1
# Out:
#             year     sex          age  suicides_no  population  \
# country
# Albania     1987    male  15-24 years           21      312900
# Albania     1987    male  35-54 years           16      308000
# Albania     1987  female  15-24 years           14      289700
# Albania     1987    male    75+ years            1       21800
# Albania     1987    male  25-34 years            9      274300
# Albania     1987  female    75+ years            1       35600
# Albania     1987  female  35-54 years            6      278800
# Albania     1987  female  25-34 years            4      257200
# Albania     1987    male  55-74 years            1      137500
# Albania     1987  female   5-14 years            0      311000
# Albania     1987  female  55-74 years            0      144600
# Albania     1987    male   5-14 years            0      338200
# Albania     1988  female    75+ years            2       36400
# Albania     1988    male  15-24 years           17      319200
# ...

# %%
df2 = df1[["year","suicides_no"]]

# %%
df = df2[["year","suicides_no"]][df2["suicides_no"]>60]

# %%
df
# Out:
#             year  suicides_no
# country
# Argentina   1985          202
# Argentina   1985          485
# Argentina   1985          414
# Argentina   1985          210
# Argentina   1985          177
# Argentina   1985          156
# Argentina   1985          142
# Argentina   1985           65
# Argentina   1985           69
# Argentina   1986          230
# Argentina   1986          530
# Argentina   1986          478
# Argentina   1986          209
# Argentina   1986          201
# Argentina   1986          186
# Argentina   1986          188
# Argentina   1986           96
# Argentina   1986          101
# Argentina   1987          200
# Argentina   1987          532
# Argentina   1987          482
# Argentina   1987          224
# Argentina   1987          192
# Argentina   1987          179
# Argentina   1987          209
# Argentina   1987           89
# Argentina   1987           93
# Argentina   1988          216
# Argentina   1988          550
# ...

# %%
colors_list = ['#5cb85c','#5bc0de']
plt.title("number of suicides", fontsize =16)
result = df.plot(kind='bar',figsize=(20,8),width = 0.8,color = colors_list,edgecolor=None)
