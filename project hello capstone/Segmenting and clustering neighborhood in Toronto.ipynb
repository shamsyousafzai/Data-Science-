# %% [markdown]
# # Project Segmenting and clustering neighborhood in Toronto

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import requests

# %%
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

# %%
r = requests.get(url, headers=header)

tables = pd.read_html(r.text)

df=pd.DataFrame(tables[0])

# %%
# The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood

df.columns=['Postcode','Borough','Neighbourhood']

df.drop([0],axis=0,inplace=True)

df.reset_index()
# Out:
#      index Postcode           Borough  \
# 0        1      M1A      Not assigned
# 1        2      M2A      Not assigned
# 2        3      M3A        North York
# 3        4      M4A        North York
# 4        5      M5A  Downtown Toronto
# 5        6      M5A  Downtown Toronto
# 6        7      M6A        North York
# 7        8      M6A        North York
# 8        9      M7A      Queen's Park
# 9       10      M8A      Not assigned
# 10      11      M9A         Etobicoke
# 11      12      M1B       Scarborough
# 12      13      M1B       Scarborough
# 13      14      M2B      Not assigned
# 14      15      M3B        North York
# 15      16      M4B         East York
# 16      17      M4B         East York
# 17      18      M5B  Downtown Toronto
# 18      19      M5B  Downtown Toronto
# 19      20      M6B        North York
# 20      21      M7B      Not assigned
# 21      22      M8B      Not assigned
# 22      23      M9B         Etobicoke
# 23      24      M9B         Etobicoke
# 24      25      M9B         Etobicoke
# 25      26      M9B         Etobicoke
# 26      27      M9B         Etobicoke
# 27      28      M1C       Scarborough
# 28      29      M1C       Scarborough
# 29      30      M1C       Scarborough
# ..     ...      ...               ...
# 258    259      M9X      Not assigned
# 259    260      M1Y      Not assigned
# 260    261      M2Y      Not assigned
# 261    262      M3Y      Not assigned
# 262    263      M4Y  Downtown Toronto
# 263    264      M5Y      Not assigned
# 264    265      M6Y      Not assigned
# 265    266      M7Y      East Toronto
# 266    267      M8Y         Etobicoke
# 267    268      M8Y         Etobicoke
# 268    269      M8Y         Etobicoke
# 269    270      M8Y         Etobicoke
# 270    271      M8Y         Etobicoke
# 271    272      M8Y         Etobicoke
# 272    273      M8Y         Etobicoke
# 273    274      M8Y         Etobicoke
# 274    275      M9Y      Not assigned
# 275    276      M1Z      Not assigned
# 276    277      M2Z      Not assigned
# 277    278      M3Z      Not assigned
# 278    279      M4Z      Not assigned
# 279    280      M5Z      Not assigned
# 280    281      M6Z      Not assigned
# 281    282      M7Z      Not assigned
# 282    283      M8Z         Etobicoke
# 283    284      M8Z         Etobicoke
# 284    285      M8Z         Etobicoke
# 285    286      M8Z         Etobicoke
# 286    287      M8Z         Etobicoke
# 287    288      M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# ..                                                 ...
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                               Church and Wellesley
# 263                                       Not assigned
# 264                                       Not assigned
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
# 287                                       Not assigned
#
# [288 rows x 4 columns]

# %%
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

df.drop(df[df['Borough']=="Not assigned"].index,axis=0, inplace=True)
df
# Out:
#     Postcode           Borough  \
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 9        M7A      Queen's Park
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 30       M1C       Scarborough
# 32       M3C        North York
# 33       M3C        North York
# 34       M4C         East York
# 35       M5C  Downtown Toronto
# 36       M6C              York
# 39       M9C         Etobicoke
# ..       ...               ...
# 236      M9V         Etobicoke
# 237      M1W       Scarborough
# 240      M4W  Downtown Toronto
# 241      M5W  Downtown Toronto
# 244      M8W         Etobicoke
# 245      M8W         Etobicoke
# 246      M9W         Etobicoke
# 247      M1X       Scarborough
# 250      M4X  Downtown Toronto
# 251      M4X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 253      M5X  Downtown Toronto
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 258      M8X         Etobicoke
# 263      M4Y  Downtown Toronto
# 266      M7Y      East Toronto
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M8Y         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M8Z         Etobicoke
#
#                                          Neighbourhood
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Not assigned
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# 32                                     Flemingdon Park
# 33                                     Don Mills South
# 34                                    Woodbine Heights
# 35                                      St. James Town
# 36                                  Humewood-Cedarvale
# 39                                   Bloordale Gardens
# ..                                                 ...
# 236                                        Thistletown
# 237                                    L'Amoreaux West
# 240                                           Rosedale
# 241                    Stn A PO Boxes 25 The Esplanade
# 244                                          Alderwood
# 245                                        Long Branch
# 246                                          Northwest
# 247                                        Upper Rouge
# 250                                        Cabbagetown
# 251                                     St. James Town
# 252                               First Canadian Place
# 253                                   Underground city
# 256                                       The Kingsway
# 257                                    Montgomery Road
# 258                                     Old Mill North
# 263                               Church and Wellesley
# 266  Business Reply Mail Processing Centre 969 Eastern
# 267                                         Humber Bay
# 268                                   King's Mill Park
# 269                           Kingsway Park South East
# 270                                          Mimico NE
# 271                                     Old Mill South
# 272                                 The Queensway East
# 273                              Royal York South East
# 274                                           Sunnylea
# 283                           Kingsway Park South West
# 284                                          Mimico NW
# 285                                 The Queensway West
# 286                              Royal York South West
# 287                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
# More than one neighborhood can exist in one postal code area. 
# For example, in the table on the Wikipedia page, 
# you will notice that M5A is listed twice and has two neighborhoods: 
# Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods 
# separated with a comma as shown in row 11 in the above table.

df1=df.groupby("Postcode").agg(lambda x:','.join(set(x)))

# %%
# If a cell has a borough but a Not assigned neighborhood, 
# then the neighborhood will be the same as the borough. 
# So for the 9th cell in the table on the Wikipedia page, 
# the value of the Borough and the Neighborhood columns will be Queen's Park.

df1.loc[df1['Neighbourhood']=="Not assigned",'Neighbourhood']=df1.loc[df1['Neighbourhood']=="Not assigned",'Borough']

df1.shape
# Out:
# (103, 2)

# %%
# Install geocoder if required
# !conda install -c conda-forge geocoder --yes
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Shams\AppData\Local\Continuum\anaconda3
#
#   added / updated specs:
#     - geocoder
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geocoder-1.38.1            |             py_1          53 KB  conda-forge
#     ratelim-0.1.6              |             py_2           6 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          59 KB
#
# The following NEW packages will be INSTALLED:
#
#   geocoder           conda-forge/noarch::geocoder-1.38.1-py_1
#   ratelim            conda-forge/noarch::ratelim-0.1.6-py_2
#
#
#
# Downloading and Extracting Packages
#
# ratelim-0.1.6        | 6 KB      |            |   0%
# ratelim-0.1.6        | 6 KB      | ########## | 100%
#
# geocoder-1.38.1      | 53 KB     |            |   0%
# geocoder-1.38.1      | 53 KB     | ###        |  30%
# geocoder-1.38.1      | 53 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# Only run once to get the Latitude / Longitude then Pickled
import geocoder

# Create a copy of the part_01 dataframe
part_02 = part_01.copy()

# Create a list of all the Postal Codes
postal_codes = part_01['Postcode'].tolist()

# Search for the Latitude and Longitude of each postal code
for postal_code in postal_codes:
    # initialize your variable to None
    lat_lng_coords = None

    # loop until you get the coordinates
    print('{}, Toronto, Ontario'.format(postal_code))
    while(lat_lng_coords is None):
      g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
      # g = geocoder.opencage('{}, Toronto, Ontario'.format(postal_code), key='13aa077d21ae42f287ec8607e07b2159')

      lat_lng_coords = g.latlng

    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    
    part_02.loc[part_02.Postcode == postal_code, 'Latitude'] = latitude
    part_02.loc[part_02.Postcode == postal_code, 'Longitude'] = longitude
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2c6e6abde876> in <module>
#       3
#       4 # Create a copy of the part_01 dataframe
# ----> 5 part_02 = part_01.copy()
#       6
#       7 # Create a list of all the Postal Codes
#
# NameError: name 'part_01' is not defined
