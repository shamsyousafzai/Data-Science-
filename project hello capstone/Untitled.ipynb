# %%
import pandas as pd

# %%
import requests
import lxml.html as lh

# %%
df = pd.read_csv("pcode_canada.csv")

# %%
df
# Out:
#     Unnamed: 0 PostalCode           Borough  \
# 0            0        M5G  Downtown Toronto
# 1            1        M2H        North York
# 2            2        M4B         East York
# 3            3        M1J       Scarborough
# 4            4        M4G         East York
# 5            5        M4M      East Toronto
# 6            6        M1R       Scarborough
# 7            7        M9V         Etobicoke
# 8            8        M9L        North York
# 9            9        M5V  Downtown Toronto
# 10          10        M1B       Scarborough
# 11          11        M5A  Downtown Toronto
#
#                                          Neighborhood
# 0                                 Central  Bay Street
# 1                                   Hillcrest Village
# 2                     Parkview Hill, Woodbine Gardens
# 3                                 Scarborough Village
# 4                                             Leaside
# 5                                     Studio District
# ...
