# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cars.csv", header = 0 , encoding = "unicode_escape")

# %%
df
# Out:
#                     Brand Condition    Fuel  KMs Driven  \
# 0                  Toyota      Used  Diesel         1.0
# 1                  Suzuki      Used  Petrol    100000.0
# 2                  Suzuki      Used     CNG     12345.0
# 3                  Suzuki      Used  Petrol     94000.0
# 4                  Toyota      Used  Petrol    100000.0
# 5                  Toyota      Used  Petrol     80000.0
# 6                  Suzuki       New     CNG     65000.0
# 7                  Toyota       New  Petrol     10241.0
# 8                  Suzuki      Used     CNG     83000.0
# 9                   Honda      Used  Petrol         1.0
# 10                 Suzuki      Used     CNG       123.0
# 11                 Suzuki      Used     CNG     73000.0
# 12                 Toyota      Used  Petrol     78000.0
# 13                  Honda      Used  Petrol         1.0
# 14                  Honda      Used     CNG    170000.0
# 15                 Suzuki      Used  Petrol    200000.0
# ...

# %%
df.set_index("Brand",inplace= True)

# %%
Brand= (df.loc[["Toyota"]]).head(100)

# %%
Brand.plot()

# %%
Suzuki= df.loc[["Suzuki"]].head(1000)
Suzuki
# Out:
#        Condition    Fuel  KMs Driven        Model    Price Registered City  \
# Brand
# Suzuki      Used  Petrol    100000.0        Bolan   380000         Karachi
# Suzuki      Used     CNG     12345.0        Bolan   340000         Karachi
# Suzuki      Used  Petrol     94000.0         Alto   535000         Karachi
# Suzuki       New     CNG     65000.0   Cultus VXL   450000         Karachi
# Suzuki      Used     CNG     83000.0         Alto   490000         Karachi
# Suzuki      Used     CNG       123.0       Khyber   230000         Karachi
# Suzuki      Used     CNG     73000.0        Liana   535000         Karachi
# Suzuki      Used  Petrol    200000.0         Alto   425000         Karachi
# Suzuki      Used     CNG     10000.0     Margalla   400000         Karachi
# Suzuki      Used     CNG     10000.0       Khyber   175000         Karachi
# Suzuki      Used     CNG     88000.0         Alto   465000         Karachi
# ...

# %%
Suzuki.plot(kind= "bar", color = "blue")
