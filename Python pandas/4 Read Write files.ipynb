# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pak_pop.csv").head()

# %%
df
# Out:
#    Year  TotalPopulation  PercentMale  PercentFemale  PopDensity  \
# 0  2019       216565.318     0.514614       0.485386      245.56
# 1  2018       212228.286     0.514619       0.485381      240.65
# 2  2017       207906.209     0.514626       0.485374      235.74
# 3  2016       203631.353     0.514643       0.485357      230.90
# 4  2015       199426.964     0.514678       0.485322      226.13
#
#    TotalPopulationRank  GrowthRate
# 0                    5    0.020436
# 1                    5    0.020789
# 2                    5    0.020993
# 3                    6    0.021082
# 4                    6    0.021364

# %%
df = pd.read_csv("pak_pop.csv", skiprows = 1).head()

# %%
df
# Out:
#    2019  216565.318  0.5146141682760117  0.4853858271064437  245.56  5  \
# 0  2018  212228.286            0.514619            0.485381  240.65  5
# 1  2017  207906.209            0.514626            0.485374  235.74  5
# 2  2016  203631.353            0.514643            0.485357  230.90  6
# 3  2015  199426.964            0.514678            0.485322  226.13  6
# 4  2010  179424.641            0.515130            0.484870  203.45  6
#
#    0.020435692535348382
# 0              0.020789
# 1              0.020993
# 2              0.021082
# 3              0.021364
# 4              0.022793

# %%
df = pd.read_csv("pak_pop.csv", header = 2)

# %%
df
# Out:
#     2018  212228.28600000002  0.5146192576799117  0.4853807517439027  240.65  \
# 0   2017          207906.209            0.514626            0.485374  235.74
# 1   2016          203631.353            0.514643            0.485357  230.90
# 2   2015          199426.964            0.514678            0.485322  226.13
# 3   2010          179424.641            0.515130            0.484870  203.45
# 4   2005          160304.008            0.515746            0.484254  181.77
# 5   2000          142343.578            0.516171            0.483829  161.40
# 6   1995          123776.839            0.516938            0.483062  140.35
# 7   1990          107647.921            0.518549            0.481451  122.06
# 8   1985           92191.510            0.520630            0.479370  104.54
# 9   1980           78054.343            0.523378            0.476622   88.51
# 10  1975           66816.877            0.526277            0.473723   75.76
# ...

# %%
df = pd.read_csv("pak_pop.csv", header = None)

# %%
df
# Out:
#        0                   1                   2                    3  \
# 0   Year     TotalPopulation         PercentMale        PercentFemale
# 1   2019          216565.318  0.5146141682760117   0.4853858271064437
# 2   2018  212228.28600000002  0.5146192576799117   0.4853807517439027
# 3   2017  207906.20899999997  0.5146256502613639   0.4853743545484974
# 4   2016          203631.353  0.5146428261467182  0.48535718858578714
# 5   2015  199426.96399999998  0.5146781003997032  0.48532184444225906
# 6   2010          179424.641  0.5151298533181962   0.4848701578285449
# 7   2005          160304.008  0.5157464808989679   0.4842535128628849
# 8   2000          142343.578   0.516171463667999   0.4838285714582782
# 9   1995          123776.839  0.5169378578168408  0.48306210986693554
# 10  1990          107647.921  0.5185493549847563   0.4814506171466144
# 11  1985            92191.51  0.5206298931430887   0.4793700526219823
# ...

# %%
df = pd.read_csv("pak_pop.csv", header = None , names = ["A","B","C"])

# %%
df
# Out:
#                                                                          A  \
# Year TotalPopulation    PercentMale        PercentFemale        PopDensity
# 2019 216565.318         0.5146141682760117 0.4853858271064437       245.56
# 2018 212228.28600000002 0.5146192576799117 0.4853807517439027       240.65
# 2017 207906.20899999997 0.5146256502613639 0.4853743545484974       235.74
# 2016 203631.353         0.5146428261467182 0.48535718858578714      230.90
# 2015 199426.96399999998 0.5146781003997032 0.48532184444225906      226.13
# 2010 179424.641         0.5151298533181962 0.4848701578285449       203.45
# 2005 160304.008         0.5157464808989679 0.4842535128628849       181.77
# 2000 142343.578         0.516171463667999  0.4838285714582782       161.40
# 1995 123776.839         0.5169378578168408 0.48306210986693554      140.35
# 1990 107647.921         0.5185493549847563 0.4814506171466144       122.06
# ...

# %%
cs = pd.read_excel("Airline.xls")

# %%
cs
# Out:
#     YEAR       Y      W              R      L      K
# 0   1948   1.214  0.243         0.1454  1.415  0.612
# 1   1949   1.354  0.260         0.2181  1.384  0.559
# 2   1950   1.569  0.278         0.3157  1.388  0.573
# 3   1951   1.948  0.297          0.394  1.550  0.564
# 4   1952   2.265  0.310         0.3559  1.802  0.574
# 5   1953   2.731  0.322         0.3593  1.926  0.711
# 6   1954   3.025  0.335         0.4025  1.964  0.776
# 7   1955   3.562  0.350         0.3961  2.116  0.827
# 8   1956   3.979  0.361  not available  2.435    0.8
# 9   1957    4.42  0.379         0.3045  2.707  0.921
# 10  1958   4.563  0.391         0.3284  2.706  1.067
# 11  1959   5.385  0.426         0.3856  2.846  1.083
# 12  1960   5.554  0.441         0.3193  3.089  1.481
# 13  1961   5.465  0.460         0.3079  3.122  1.736
# 14  1962   5.825  0.485         0.3783  3.184  1.926
# 15  1963   6.876  0.506          0.418  3.263  2.041
# 16  1964   7.823  0.538         0.5163  3.412  1.997
# ...

# %%
cs = pd.read_excel("Airline.xls", na_values=["not available","n.a"])

# %%
cs
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361     NaN  2.435  0.800
# 9   1957    4.42  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965    9.12  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
cs = pd.read_excel("Airline.xls", nrows = 6)

# %%
cs
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574
# 5  1953  2.731  0.322  0.3593  1.926  0.711

# %%
cs.columns
# Out:
# Index(['YEAR', 'Y', 'W', 'R', 'L', 'K'], dtype='object')

# %%
cs.to_csv("Airline1.csv",index = False,columns=["YEAR","Y","W"])
