# %%
import pandas as pd
weather_data = {"day":["1/1/2019","1/2/2019","1/3/2019","1/4/2019","1/5/2019","1/6/2019"],"temperature":[32,35,28,40,34,25],
                "windspeed":[6,7,4,7,5,6],"event":["rain","sunny","rain","hot","sunny","cold"]}

# %%
df = pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2019           32          6   rain
# 1  1/2/2019           35          7  sunny
# 2  1/3/2019           28          4   rain
# 3  1/4/2019           40          7    hot
# 4  1/5/2019           34          5  sunny
# 5  1/6/2019           25          6   cold

# %%
df.to_csv("Weather_data.csv")

# %%
cs = pd.read_csv("sample_data.csv")

# %%
cs
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
ex = pd.read_excel("airline.xls")

# %%
ex
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
weather_data1= [("15/07/2019",32,6,"rain"),
                ("16/07/2019",35,7,"sunny"),
                ("17/07/2019",40,8,"hot"),
                ("18/07/2019",5,2,"snow")]

# %%
da = pd.DataFrame(weather_data1, columns = ["day","temperature","windspeed","event"])

# %%
da
# Out:
#           day  temperature  windspeed  event
# 0  15/07/2019           32          6   rain
# 1  16/07/2019           35          7  sunny
# 2  17/07/2019           40          8    hot
# 3  18/07/2019            5          2   snow

# %%
weather_d = [
    {"day":"15/07/2019", "temperature":32, "windspeed":6, "event":"rain"},
    {"day":"16/07/2019", "temperature":35, "windspeed":8, "event":"sunny"},
    {"day":"17/07/2019", "temperature":30, "windspeed":5, "event":"rain"},
    {"day":"18/07/2019", "temperature":5, "windspeed":3, "event":"snow"},
    {"day":"19/07/2019", "temperature":40, "windspeed":6, "event":"hot"},
]

# %%
df2 =pd.DataFrame(weather_d)

# %%
df2
# Out:
#           day  event  temperature  windspeed
# 0  15/07/2019   rain           32          6
# 1  16/07/2019  sunny           35          8
# 2  17/07/2019   rain           30          5
# 3  18/07/2019   snow            5          3
# 4  19/07/2019    hot           40          6

# %%
df2.to_csv("weather2.csv",index = False)   # if i want to remove the index

# %%
df2.columns
# Out:
# Index(['day', 'event', 'temperature', 'windspeed'], dtype='object')

# %%
df2.to_csv("weather3.csv",columns = ["day","event"],index = False)

# %%
da.shape
# Out:
# (4, 4)

# %%
rows , columns = da.shape

# %%
rows
# Out:
# 4

# %%
columns
# Out:
# 4
