# %% [markdown]
# # Project 1 Population Growth

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("countries.csv")
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# 5     Afghanistan  1977    14880372
# 6     Afghanistan  1982    12881816
# 7     Afghanistan  1987    13867957
# 8     Afghanistan  1992    16317921
# 9     Afghanistan  1997    22227415
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 12        Albania  1952     1282697
# 13        Albania  1957     1476505
# 14        Albania  1962     1728137
# 15        Albania  1967     1984060
# 16        Albania  1972     2263554
# 17        Albania  1977     2509048
# 18        Albania  1982     2780097
# 19        Albania  1987     3075321
# 20        Albania  1992     3326498
# 21        Albania  1997     3428038
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 24        Algeria  1952     9279525
# ...

# %%
Afghanistan = df["country"] == "Afghanistan"
Albania = df["country"] == "Albania"
Algeria = df["country"] == "Algeria"
Australia = df["country"] == "Australia"
Austria = df["country"] == "Austria"
Bahrain = df["country"] == "Bahrain"
Bangladesh = df["country"] == "Bangladesh"
Belgium = df["country"] == "Belgium"
Benin = df["country"] == "Benin"
Bolivia = df["country"] == "Bolivia"
Bosnia_and_Herzegovina = df["country"] == "Bosnia and Herzegovina"
Botswana = df["country"] == "Botswana"
Brazil = df["country"] == "Brazil"
Bulgaria = df["country"] == "Bulgaria"
Burkina_Faso = df["country"] == "Burkina faso"
Burundi = df["country"] == "Burundi"
Cambodia = df["country"] == "Cambodia"
Cameroon = df["country"] == "Cameroon"
Canada = df["country"] == "Canada"
Central_African_Republic = df["country"] == "Central African Republic"
Chad = df["country"] == "Chad"
Chile = df["country"] == "Chile"
China = df["country"] == "China"
Colombia = df["country"] == "Colombia"
Comoros = df["country"] == "Comoros"
Costa_Rica = df["country"] == "Costa Rica"
England = df["country"] == "England"
India = df["country"] == "India"
Iran = df["country"] == "Iran"
Jamaica = df["country"] == "Jamaica"
Japan = df["country"] == "Japan"
Kenya = df["country"] == "Kenya"
Kuwait = df["country"] == "Kuwait"
Lebanon = df["country"] == "Lebanon"
Lesotho = df["country"] == "Lesotho"
Liberia = df["country"] == "Liberia"
Libya = df["country"] == "Libya"
Madagascar = df["country"] == "Madagascar"
Malawi = df["country"] == "Malawi"
Malaysia = df["country"] == "Malaysia"
Mali = df["country"] == "Mali"
Mauritania = df["country"] == "Mauritania"
Mexico = df["country"] == "Mexico"
Mongolia = df["country"] == "Mongolia"
Morocco = df["country"] == "Morocco"
Myanmar = df["country"] == "Myanmar"
Nepal = df["country"] == "Nepal"
Netherlands = df["country"] == "Netherlands"
New_Zealand = df["country"] == "New Zealands"
Norway = df["country"] == "Norway"
Oman = df["country"] == "Oman"
Pakistan = df["country"] == "Pakistan"
Peru = df["country"] == "Peru"
Philippines = df["country"] == "Philippines"
Poland = df["country"] == "Poland"
Portugal = df["country"] == "Portugal"
Puerto_Rico = df["country"] == "Puerto Rico"
Reunion = df["country"] == "Reunion"
Romania = df["country"] == "Romania"
Rwanda = df["country"] == "Rwanda"
Senegal = df["country"] == "Senegal"
Serbia = df["country"] == "Serbia"
Srilanka = df["country"] == "Srilanka"
Taiwan = df["country"] == "Taiwan"
Thailand = df["country"] == "Thailand"
Tunisia = df["country"] == "Tunisia"
Turkey = df["country"] == "Turkey"
Uganda = df["country"] == "Uganda"
United_Kingdom = df["country"] == "United Kingdom"
United_States = df["country"] == "United States"
Yemen = df["country"] == "Yemen"
Zimbabwe = df["country"] == "Zimbabwe"

# %%
Pak_country = df[Pakistan].country
Pak_year = df[Pakistan].year
Pak_population = df[Pakistan].population

# %%
Ind_country = df[India].country
Ind_year = df[India].year
Ind_population = df[India].population

# %%
plt.plot(Pak_year,Pak_population)
plt.plot(Ind_year,Ind_population)

# %%
Pak = df[Pakistan]
Ind = df[India]

# %%
pak.plot()
Ind.plot()
