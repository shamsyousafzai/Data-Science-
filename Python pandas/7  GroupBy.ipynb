# %%
import pandas as pd

# %%
df = pd.read_csv("countries.csv")

# %%
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# 5     Afghanistan  1977    14880372
# 6     Afghanistan  1982    12881816
# 7     Afghanistan  1987    13867957
# 8     Afghanistan  1992    16317921
# 9     Afghanistan  1997    22227415
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 12        Albania  1952     1282697
# 13        Albania  1957     1476505
# 14        Albania  1962     1728137
# 15        Albania  1967     1984060
# 16        Albania  1972     2263554
# 17        Albania  1977     2509048
# 18        Albania  1982     2780097
# 19        Albania  1987     3075321
# 20        Albania  1992     3326498
# 21        Albania  1997     3428038
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 24        Algeria  1952     9279525
# ...

# %%
g = df.groupby("country")

# %%
g

# %%
for country , country_df in g:
    print(country)
    print(country_df)
# Out:
# Afghanistan
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923
# Albania
#     country  year  population
# 12  Albania  1952     1282697
# 13  Albania  1957     1476505
# 14  Albania  1962     1728137
# 15  Albania  1967     1984060
# 16  Albania  1972     2263554
# 17  Albania  1977     2509048
# 18  Albania  1982     2780097
# 19  Albania  1987     3075321
# 20  Albania  1992     3326498
# 21  Albania  1997     3428038
# 22  Albania  2002     3508512
# 23  Albania  2007     3600523
# Algeria
#     country  year  population
# 24  Algeria  1952     9279525
# ...

# %%
f = df.groupby("year")

# %%
for year , year_df in f:
    print(year)
    print(year_df)
# Out:
# 1952
#                        country  year  population
# 0                  Afghanistan  1952     8425333
# 12                     Albania  1952     1282697
# 24                     Algeria  1952     9279525
# 36                      Angola  1952     4232095
# 48                   Argentina  1952    17876956
# 60                   Australia  1952     8691212
# 72                     Austria  1952     6927772
# 84                     Bahrain  1952      120447
# 96                  Bangladesh  1952    46886859
# 108                    Belgium  1952     8730405
# 120                      Benin  1952     1738315
# 132                    Bolivia  1952     2883315
# 144     Bosnia and Herzegovina  1952     2791000
# 156                   Botswana  1952      442308
# 168                     Brazil  1952    56602560
# 180                   Bulgaria  1952     7274900
# 192               Burkina Faso  1952     4469979
# 204                    Burundi  1952     2445618
# ...

# %%
g.get_group("Benin")
# Out:
#     country  year  population
# 120   Benin  1952     1738315
# 121   Benin  1957     1925173
# 122   Benin  1962     2151895
# 123   Benin  1967     2427334
# 124   Benin  1972     2761407
# 125   Benin  1977     3168267
# 126   Benin  1982     3641603
# 127   Benin  1987     4243788
# 128   Benin  1992     4981671
# 129   Benin  1997     6066080
# 130   Benin  2002     7026113
# 131   Benin  2007     8078314

# %%
f.get_group(1957)
# Out:
#                        country  year  population
# 1                  Afghanistan  1957     9240934
# 13                     Albania  1957     1476505
# 25                     Algeria  1957    10270856
# 37                      Angola  1957     4561361
# 49                   Argentina  1957    19610538
# 61                   Australia  1957     9712569
# 73                     Austria  1957     6965860
# 85                     Bahrain  1957      138655
# 97                  Bangladesh  1957    51365468
# 109                    Belgium  1957     8989111
# 121                      Benin  1957     1925173
# 133                    Bolivia  1957     3211738
# 145     Bosnia and Herzegovina  1957     3076000
# 157                   Botswana  1957      474639
# 169                     Brazil  1957    65551171
# 181                   Bulgaria  1957     7651254
# 193               Burkina Faso  1957     4713416
# 205                    Burundi  1957     2667518
# ...

# %%
g.max()
# Out:
#                           year  population
# country
# Afghanistan               2007    31889923
# Albania                   2007     3600523
# Algeria                   2007    33333216
# Angola                    2007    12420476
# Argentina                 2007    40301927
# Australia                 2007    20434176
# Austria                   2007     8199783
# Bahrain                   2007      708573
# Bangladesh                2007   150448339
# Belgium                   2007    10392226
# Benin                     2007     8078314
# Bolivia                   2007     9119152
# Bosnia and Herzegovina    2007     4552198
# Botswana                  2007     1639131
# Brazil                    2007   190010647
# Bulgaria                  2007     8971958
# Burkina Faso              2007    14326203
# Burundi                   2007     8390505
# Cambodia                  2007    14131858
# Cameroon                  2007    17696293
# Canada                    2007    33390141
# ...

# %%
g.min()
# Out:
#                           year  population
# country
# Afghanistan               1952     8425333
# Albania                   1952     1282697
# Algeria                   1952     9279525
# Angola                    1952     4232095
# Argentina                 1952    17876956
# Australia                 1952     8691212
# Austria                   1952     6927772
# Bahrain                   1952      120447
# Bangladesh                1952    46886859
# Belgium                   1952     8730405
# Benin                     1952     1738315
# Bolivia                   1952     2883315
# Bosnia and Herzegovina    1952     2791000
# Botswana                  1952      442308
# Brazil                    1952    56602560
# Bulgaria                  1952     7274900
# Burkina Faso              1952     4469979
# Burundi                   1952     2445618
# Cambodia                  1952     4693836
# Cameroon                  1952     5009067
# Canada                    1952    14785584
# ...

# %%
import matplotlib.pyplot as pd

# %%
g.plot().head()
# Out:
# country
# Afghanistan    AxesSubplot(0.125,0.125;0.775x0.755)
# Albania        AxesSubplot(0.125,0.125;0.775x0.755)
# Algeria        AxesSubplot(0.125,0.125;0.775x0.755)
# Angola         AxesSubplot(0.125,0.125;0.775x0.755)
# Argentina      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
